# %% [markdown]
# # Предсказание выживет или нет пассажир Титаника

# %% [markdown]
# **Описание задачи:** Обучить группу моделей (Logistic Regression, Decision Tree, Random Forest, Gradient Boosting, MLPClassifier) с поиском их гиперпарамтров.

# %% [markdown]
# **Исходные данные:** датасет для обучающей выборки train_students.csv и даасет для тестовой выборки tast_students.csv

# %% [markdown]
# **Формат решения:**
# Модели  Logistic Regression, Decision Tree, Random Forest, Gradient Boosting, MLPClassifier с точностью предсказания выше 80%

# %% [markdown]
# ### Оглавление
# [1. Загрузка/изучение/предобработка данных](#id-section1_)
# [2. Строим модели обучения](#id-section2_)
# [2.1. RandomForestClassifier](#id-section2.1._)
# [2.2. DecisionTreeClassifier](#id-section2.2._)
# [2.3. GradientBoostingClassifier](#id-section2.3._)
# [2.4. Logistic Regression](#id-section2.4._)
# [2.5. MLPClassifier](#id-section2.5._)
# [3. Вывод](#id-section3_)

# %% [markdown]
# ## Общие функции для работы

# %%
import os
import sys
import random
import pandas as pd
import numpy as np

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import recall_score, accuracy_score, f1_score, precision_score

from matplotlib import pyplot as plt

# %%
#фиксируем параметры псевдослучайного генератора
seed = 42
random.seed(seed)
np.random.seed(seed)

# %% [markdown]
# <div id='id-section1_'/>

# %% [markdown]
# ## 1. Загрузка/изучение/предобработка данных

# %%
train = pd.read_csv('train_students.csv')
test = pd.read_csv ('test_students.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0            710         1       3
# 1            440         0       2
# 2            841         0       3
# 3            721         1       2
# 4             40         1       3
# ..           ...       ...     ...
# 708          640         0       3
# 709          879         0       3
# 710          825         0       3
# 711          804         1       3
# 712          620         0       2
#
#                                                   Name     Sex    Age  SibSp  \
# 0    Moubarek, Master. Halim Gonios ("William George")    male    NaN      1
# 1               Kvillner, Mr. Johan Henrik Johannesson    male  31.00      0
# 2                          Alhomaki, Mr. Ilmari Rudolf    male  20.00      0
# 3                    Harper, Miss. Annie Jessie "Nina"  female   6.00      0
# 4                          Nicola-Yarred, Miss. Jamila  female  14.00      1
# ..                                                 ...     ...    ...    ...
# 708                         Thorneycroft, Mr. Percival    male    NaN      1
# 709                                 Laleff, Mr. Kristo    male    NaN      0
# 710                       Panula, Master. Urho Abraham    male   2.00      4
# 711                    Thomas, Master. Assad Alexander    male   0.42      0
# 712                                Gavey, Mr. Lawrence    male  26.00      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        1              2661  15.2458   NaN        C
# 1        0        C.A. 18723  10.5000   NaN        S
# 2        0  SOTON/O2 3101287   7.9250   NaN        S
# 3        1            248727  33.0000   NaN        S
# 4        0              2651  11.2417   NaN        C
# ..     ...               ...      ...   ...      ...
# 708      0            376564  16.1000   NaN        S
# 709      0            349217   7.8958   NaN        S
# 710      1           3101295  39.6875   NaN        S
# 711      1              2625   8.5167   NaN        C
# 712      0             31028  10.5000   NaN        S
#
# [713 rows x 12 columns]

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#преобразуем категориальные переменные в числовые в train
train = pd.get_dummies(train,columns=["Embarked"])

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0            710         1       3
# 1            440         0       2
# 2            841         0       3
# 3            721         1       2
# 4             40         1       3
# ..           ...       ...     ...
# 708          640         0       3
# 709          879         0       3
# 710          825         0       3
# 711          804         1       3
# 712          620         0       2
#
#                                                   Name     Sex    Age  SibSp  \
# 0    Moubarek, Master. Halim Gonios ("William George")    male    NaN      1
# 1               Kvillner, Mr. Johan Henrik Johannesson    male  31.00      0
# 2                          Alhomaki, Mr. Ilmari Rudolf    male  20.00      0
# 3                    Harper, Miss. Annie Jessie "Nina"  female   6.00      0
# 4                          Nicola-Yarred, Miss. Jamila  female  14.00      1
# ..                                                 ...     ...    ...    ...
# 708                         Thorneycroft, Mr. Percival    male    NaN      1
# 709                                 Laleff, Mr. Kristo    male    NaN      0
# 710                       Panula, Master. Urho Abraham    male   2.00      4
# 711                    Thomas, Master. Assad Alexander    male   0.42      0
# 712                                Gavey, Mr. Lawrence    male  26.00      0
#
#      Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  \
# 0        1              2661  15.2458   NaN           1           0
# 1        0        C.A. 18723  10.5000   NaN           0           0
# 2        0  SOTON/O2 3101287   7.9250   NaN           0           0
# 3        1            248727  33.0000   NaN           0           0
# 4        0              2651  11.2417   NaN           1           0
# ..     ...               ...      ...   ...         ...         ...
# 708      0            376564  16.1000   NaN           0           0
# 709      0            349217   7.8958   NaN           0           0
# 710      1           3101295  39.6875   NaN           0           0
# 711      1              2625   8.5167   NaN           1           0
# 712      0             31028  10.5000   NaN           0           0
#
#      Embarked_S
# 0             0
# 1             1
# 2             1
# 3             1
# 4             0
# ..          ...
# 708           1
# 709           1
# 710           1
# 711           0
# 712           1
#
# [713 rows x 14 columns]

# %%
#преобразуем категориальные переменные в числовые в test
test = pd.get_dummies(test,columns=["Embarked"])

# %%
#Замена пола на численные значения
train['Sex'].replace({'male':0, 'female':1}, inplace=True)
test['Sex'].replace({'male':0, 'female':1}, inplace=True)

# %%
#разбиение на train и test
train_X = train.drop(columns=['Survived']) # создаем train_X без колонки survived 
train_y = train['Survived'] #создаем train_y c колонкой survived 

test_X = test.drop(columns=['Survived']) 
test_y = test['Survived']

# %%
#выбор колонок для использования в виде входных признаков 
features = ['Pclass','Age', 'Sex','SibSp', 'Parch', 'Fare', 'Embarked_C','Embarked_Q', 'Embarked_S']
train_X = train_X[features]
test_X = test_X[features]

# %%
# суммируем пропуски по колонкам в train
train_X.isna().sum()
# Out:
# Pclass          0
# Age           144
# Sex             0
# SibSp           0
# Parch           0
# Fare            0
# Embarked_C      0
# Embarked_Q      0
# Embarked_S      0
# dtype: int64

# %%
#ищем средний возраст пассажиров мужского пола 1-го класса в train
mask1 = (train_X['Pclass'] == 1) & (train_X['Sex']==0) 
avg_filler1 = train_X.loc[mask1, 'Age'].median()

# %%
#обновляем значеня в train
train_X.loc[train_X['Age'].isnull() & mask1, 'Age'] = avg_filler1

# %%
#ищем средний возраст пассажиров женского пола 1-го класса в train
mask1_1 = (train_X['Pclass'] == 1) & (train_X['Sex'] == 1) 
avg_filler1_1 = train_X.loc[mask1_1, 'Age'].median()

# %%
#обновляем значеня в train
train_X.loc[train_X['Age'].isnull() & mask1_1, 'Age'] = avg_filler1_1

# %%
#ищем средний возраст пассажиров мужского пола 2-го класса в train
mask2 = (train_X['Pclass'] == 2) & (train_X['Sex'] == 0)
avg_filler2 = train_X.loc[mask2, 'Age'].median()

# %%
#обновляем значеня в train
train_X.loc[train_X['Age'].isnull() & mask2, 'Age'] = avg_filler2

# %%
#ищем средний возраст пассажиров женского пола 2-го класса в train
mask2_1 = (train_X['Pclass'] == 2) & (train_X['Sex'] == 1)
avg_filler2_1 = train_X.loc[mask2_1, 'Age'].median()

# %%
#обновляем значеня в train
train_X.loc[train_X['Age'].isnull() & mask2_1, 'Age'] = avg_filler2_1

# %%
#ищем средний возраст пассажиров мужского пола 3-го класса в train
mask3 = (train_X['Pclass'] == 3) & (train_X['Sex']==0 )
avg_filler3 = train_X.loc[mask3, 'Age'].median()

# %%
#обновляем значеня в train
train_X.loc[train_X['Age'].isnull() & mask3, 'Age'] = avg_filler3

# %%
#ищем средний возраст пассажиров женского пола 3-го класса в train
mask3_1 = (train_X['Pclass'] == 3) & (train_X['Sex'] == 1)
avg_filler3_1 = train_X.loc[mask3_1, 'Age'].median()

# %%
#обновляем значеня в train
train_X.loc[train_X['Age'].isnull() & mask3_1, 'Age'] = avg_filler3_1

# %%
test_X.isna().sum()
# Out:
# Pclass         0
# Age           33
# Sex            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
#заполняем средний возраст пассажиров мужского пола 1-го класса в tast данными из train
mask1 = (test_X['Pclass'] == 1)& (test_X['Sex'] == 0)

# %%
#обновляем значеня в tast
test_X.loc[test_X['Age'].isnull() & mask1, 'Age'] = avg_filler1

# %%
#ищем средний возраст пассажиров женского пола 1-го класса в tast данными из train
mask1_1 = (test_X['Pclass'] == 1)& (test_X['Sex'] == 1)

# %%
#обновляем значеня в tast
test_X.loc[test_X['Age'].isnull() & mask1_1, 'Age'] = avg_filler1_1

# %%
#ищем средний возраст пассажиров мужского пола 2-го класса в tast данными из train
mask2 = (test_X['Pclass'] == 2)& (test_X['Sex'] == 0)

# %%
#обновляем значеня в tast
test_X.loc[test_X['Age'].isnull() & mask2, 'Age'] = avg_filler2

# %%
#ищем средний возраст пассажиров женского пола 2-го класса в tast данными из train
mask2_1 = (test_X['Pclass'] == 2)& (test_X['Sex'] == 1)

# %%
#обновляем значеня в tast
test_X.loc[test_X['Age'].isnull() & mask2_1, 'Age'] = avg_filler2_1

# %%
#ищем средний возраст пассажиров мужского пола 3-го класса в tast данными из train
mask3 = (test_X['Pclass'] == 3)& (test_X['Sex'] == 0)

# %%
#обновляем значеня в tast
test_X.loc[test_X['Age'].isnull() & mask3, 'Age'] = avg_filler3

# %%
#ищем средний возраст пассажиров женского пола 3-го класса в tast данными из train
mask3_1 = (test_X['Pclass'] == 3)& (test_X['Sex'] == 1)

# %%
#обновляем значеня в tast
test_X.loc[test_X['Age'].isnull() & mask3_1, 'Age'] = avg_filler3_1

# %%
test_X.isna().sum()
# Out:
# Pclass        0
# Age           0
# Sex           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %% [markdown]
# <div id='id-section2_'/>

# %% [markdown]
# ## 2. Строим модели обучения

# %% [markdown]
# <div id='id-section2.1._'/>

# %% [markdown]
# ### 2.1. RandomForestClassifier

# %%
#RandomForestClassifier
clf = RandomForestClassifier(random_state=seed, max_depth=13) #  с учетом параметров наилучшей модел
clf.fit(train_X, train_y)
preds_train = clf.predict(train_X) # predictions based on train_X 
preds_test = clf.predict(test_X) # predictions based on test_X

print('####### TRAIN RESULTS #######')
print('Recall: ', round(recall_score(train_y, preds_train), 2))
print('Accuracy: ', round(accuracy_score(train_y, preds_train), 2))
print('Precision: ', round(precision_score(train_y, preds_train), 2))
print('F1 score: ', round(f1_score(train_y, preds_train), 2))

print('####### TEST RESULTS #######')
print('Recall: ', round(recall_score(test_y, preds_test), 2))
print('Accuracy: ', round(accuracy_score(test_y, preds_test), 2))
print('Precision: ', round(precision_score(test_y, preds_test), 2))
print('F1 score: ', round(f1_score(test_y, preds_test), 2))
results = pd.DataFrame()
for max_depth in range(1, 100, 2): # строим несколько моделей и смотрим их результаты 
    clf = RandomForestClassifier(random_state=seed, max_depth=max_depth)
    clf.fit(train_X, train_y)
    preds_train = clf.predict(train_X)
    preds_test = clf.predict(test_X)
    
    results_dict = {
                    'max_depth':[max_depth],
                    'recall_train':[recall_score(train_y, preds_train)], 
                    'acc_train':[accuracy_score(train_y, preds_train)],
                    'prec_train':[precision_score(train_y, preds_train)],
                    'f1_train':[f1_score(train_y, preds_train)],
                    'recall_test':[recall_score(test_y, preds_test)],
                    'acc_test':[accuracy_score(test_y, preds_test)],
                    'prec_test':[precision_score(test_y, preds_test)],
                    'f1_test':[f1_score(test_y, preds_test)]
                   }
    
    results_df = pd.DataFrame.from_dict(results_dict)
    results = results.append(results_df)

results.reset_index(inplace=True, drop=True)
# Out:
# ####### TRAIN RESULTS #######
# Recall:  0.94
# Accuracy:  0.97
# Precision:  0.99
# F1 score:  0.96
# ####### TEST RESULTS #######
# Recall:  0.72
# Accuracy:  0.81
# Precision:  0.76
# F1 score:  0.74

# %%
results[results.recall_test == results.recall_test.max()]
# Out:
#    max_depth  recall_train  acc_train  prec_train  f1_train  recall_test  \
# 1          3      0.700361   0.820477    0.811715  0.751938     0.723077
# 3          7      0.808664   0.903226    0.933333  0.866538     0.723077
# 4          9      0.873646   0.934081    0.952756  0.911488     0.723077
# 5         11      0.913357   0.959327    0.980620  0.945794     0.723077
# 6         13      0.938628   0.971950    0.988593  0.962963     0.723077
#
#    acc_test  prec_test   f1_test
# 1  0.825843   0.783333  0.752000
# 3  0.842697   0.824561  0.770492
# 4  0.842697   0.824561  0.770492
# 5  0.825843   0.783333  0.752000
# 6  0.814607   0.758065  0.740157

# %% [markdown]
# <div id='id-section2.2._'/>

# %% [markdown]
# ### 2.2. DecisionTreeClassifier

# %%
#DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=5, random_state=seed)
clf.fit(train_X, train_y)
preds_train = clf.predict(train_X) # predictions based on train_X 
preds_test = clf.predict(test_X) # predictions based on test_X

print('####### TRAIN RESULTS #######')
print('Recall: ', round(recall_score(train_y, preds_train), 2))
print('Accuracy: ', round(accuracy_score(train_y, preds_train), 2))
print('Precision: ', round(precision_score(train_y, preds_train), 2))
print('F1 score: ', round(f1_score(train_y, preds_train), 2))

print('####### TEST RESULTS #######')
print('Recall: ', round(recall_score(test_y, preds_test), 2))
print('Accuracy: ', round(accuracy_score(test_y, preds_test), 2))
print('Precision: ', round(precision_score(test_y, preds_test), 2))
print('F1 score: ', round(f1_score(test_y, preds_test), 2))
results = pd.DataFrame()
for max_depth in range(1, 100, 2):
    clf = DecisionTreeClassifier(random_state=seed, max_depth=max_depth)
    clf.fit(train_X, train_y)
    preds_train = clf.predict(train_X)
    preds_test = clf.predict(test_X)
    
    results_dict = {
                    'max_depth':[max_depth],
                    'recall_train':[recall_score(train_y, preds_train)], 
                    'acc_train':[accuracy_score(train_y, preds_train)],
                    'prec_train':[precision_score(train_y, preds_train)],
                    'f1_train':[f1_score(train_y, preds_train)],
                    'recall_test':[recall_score(test_y, preds_test)],
                    'acc_test':[accuracy_score(test_y, preds_test)],
                    'prec_test':[precision_score(test_y, preds_test)],
                    'f1_test':[f1_score(test_y, preds_test)]
                   }
    
    results_df = pd.DataFrame.from_dict(results_dict)
    results = results.append(results_df)

results.reset_index(inplace=True, drop=True)
# Out:
# ####### TRAIN RESULTS #######
# Recall:  0.79
# Accuracy:  0.85
# Precision:  0.81
# F1 score:  0.8
# ####### TEST RESULTS #######
# Recall:  0.8
# Accuracy:  0.8
# Precision:  0.7
# F1 score:  0.75

# %%
results[results.recall_test == results.recall_test.max()]
# Out:
#    max_depth  recall_train  acc_train  prec_train  f1_train  recall_test  \
# 2          5      0.790614   0.845722    0.808118   0.79927          0.8
#
#    acc_test  prec_test   f1_test
# 2  0.803371   0.702703  0.748201

# %% [markdown]
# <div id='id-section2.3._'/>

# %% [markdown]
# ### 2.3. GradientBoostingClassifier

# %%
# GradientBoostingClassifier
clf = GradientBoostingClassifier(random_state=seed, max_depth=5)  
clf.fit(train_X, train_y) 
preds_train = clf.predict(train_X) 
preds_test = clf.predict(test_X) 

print('####### TRAIN RESULTS #######')
print('Recall: ', round(recall_score(train_y, preds_train), 2))
print('Accuracy: ', round(accuracy_score(train_y, preds_train), 2))
print('Precision: ', round(precision_score(train_y, preds_train), 2))
print('F1 score: ', round(f1_score(train_y, preds_train), 2))

print('####### TEST RESULTS #######')
print('Recall: ', round(recall_score(test_y, preds_test), 2))
print('Accuracy: ', round(accuracy_score(test_y, preds_test), 2))
print('Precision: ', round(precision_score(test_y, preds_test), 2))
print('F1 score: ', round(f1_score(test_y, preds_test), 2))
results = pd.DataFrame()
for max_depth in range(1, 50, 2):
    clf = GradientBoostingClassifier(random_state=seed, max_depth=max_depth)
    clf.fit(train_X, train_y)
    preds_train = clf.predict(train_X)
    preds_test = clf.predict(test_X)
    
    results_dict = {
                    'max_depth':[max_depth],
                    'recall_train':[recall_score(train_y, preds_train)], 
                    'acc_train':[accuracy_score(train_y, preds_train)],
                    'prec_train':[precision_score(train_y, preds_train)],
                    'f1_train':[f1_score(train_y, preds_train)],
                    'recall_test':[recall_score(test_y, preds_test)],
                    'acc_test':[accuracy_score(test_y, preds_test)],
                    'prec_test':[precision_score(test_y, preds_test)],
                    'f1_test':[f1_score(test_y, preds_test)]
                   }
    
    results_df = pd.DataFrame.from_dict(results_dict)
    results = results.append(results_df)

results.reset_index(inplace=True, drop=True)
# Out:
# ####### TRAIN RESULTS #######
# Recall:  0.94
# Accuracy:  0.97
# Precision:  0.98
# F1 score:  0.96
# ####### TEST RESULTS #######
# Recall:  0.77
# Accuracy:  0.82
# Precision:  0.75
# F1 score:  0.76

# %%
results[results.recall_test == results.recall_test.max()]
# Out:
#    max_depth  recall_train  acc_train  prec_train  f1_train  recall_test  \
# 2          5      0.938628   0.967742    0.977444  0.957643     0.769231
#
#    acc_test  prec_test   f1_test
# 2  0.820225   0.746269  0.757576

# %% [markdown]
# <div id='id-section2.4._'/>

# %% [markdown]
# ### 2.4. Logistic Regression

# %%
#Logistic Regression
clf = LogisticRegression(random_state=seed, C=27, max_iter=500)  
clf.fit(train_X, train_y) 
preds_train = clf.predict(train_X) 
preds_test = clf.predict(test_X) 

print('####### РЕЗУЛЬТАТЫ ДЛЯ ОБУЧЕНИЯ #######')
print('Recall: ', round(recall_score(train_y, preds_train), 2))
print('Accuracy: ', round(accuracy_score(train_y, preds_train), 2))
print('Precision: ', round(precision_score(train_y, preds_train), 2))
print('F1 score: ', round(f1_score(train_y, preds_train), 2))

print('####### РЕЗУЛЬТАТЫ ДЛЯ ТЕСТА #######')
print('Recall: ', round(recall_score(test_y, preds_test), 2))
print('Accuracy: ', round(accuracy_score(test_y, preds_test), 2))
print('Precision: ', round(precision_score(test_y, preds_test), 2))
print('F1 score: ', round(f1_score(test_y, preds_test), 2))

results = pd.DataFrame()
for C_search in range(1, 100, 2):
    clf = LogisticRegression(random_state=seed, C=C_search, max_iter=1000)
    clf.fit(train_X, train_y)
    preds_train = clf.predict(train_X)
    preds_test = clf.predict(test_X)
    
    results_dict = {
                    'C_search':[C_search],
                    'recall_train':[recall_score(train_y, preds_train)], 
                    'acc_train':[accuracy_score(train_y, preds_train)],
                    'prec_train':[precision_score(train_y, preds_train)],
                    'f1_train':[f1_score(train_y, preds_train)],
                    'recall_test':[recall_score(test_y, preds_test)],
                    'acc_test':[accuracy_score(test_y, preds_test)],
                    'prec_test':[precision_score(test_y, preds_test)],
                    'f1_test':[f1_score(test_y, preds_test)]
                   }
    
    results_df = pd.DataFrame.from_dict(results_dict)
    results = results.append(results_df)

results.reset_index(inplace=True, drop=True)
# Out:
# ####### РЕЗУЛЬТАТЫ ДЛЯ ОБУЧЕНИЯ #######
# Recall:  0.7
# Accuracy:  0.81
# Precision:  0.79
# F1 score:  0.74
# ####### РЕЗУЛЬТАТЫ ДЛЯ ТЕСТА #######
# Recall:  0.71
# Accuracy:  0.8
# Precision:  0.73
# F1 score:  0.72

# %%
results[results.recall_test == results.recall_test.max()]
# Out:
#     C_search  recall_train  acc_train  prec_train  f1_train  recall_test  \
# 0          1      0.703971   0.810659    0.786290  0.742857     0.707692
# 1          3      0.703971   0.810659    0.786290  0.742857     0.707692
# 2          5      0.703971   0.810659    0.786290  0.742857     0.707692
# 3          7      0.703971   0.810659    0.786290  0.742857     0.707692
# 4          9      0.703971   0.810659    0.786290  0.742857     0.707692
# 5         11      0.703971   0.810659    0.786290  0.742857     0.707692
# 6         13      0.703971   0.809257    0.783133  0.741445     0.707692
# 7         15      0.703971   0.810659    0.786290  0.742857     0.707692
# 8         17      0.703971   0.810659    0.786290  0.742857     0.707692
# 9         19      0.703971   0.810659    0.786290  0.742857     0.707692
# 10        21      0.703971   0.810659    0.786290  0.742857     0.707692
# 11        23      0.703971   0.810659    0.786290  0.742857     0.707692
# 12        25      0.703971   0.810659    0.786290  0.742857     0.707692
# 13        27      0.703971   0.810659    0.786290  0.742857     0.707692
# 14        29      0.703971   0.810659    0.786290  0.742857     0.707692
# 15        31      0.703971   0.810659    0.786290  0.742857     0.707692
# 16        33      0.703971   0.810659    0.786290  0.742857     0.707692
# 17        35      0.703971   0.810659    0.786290  0.742857     0.707692
# 18        37      0.703971   0.810659    0.786290  0.742857     0.707692
# 19        39      0.703971   0.809257    0.783133  0.741445     0.707692
# 20        41      0.703971   0.810659    0.786290  0.742857     0.707692
# 21        43      0.703971   0.809257    0.783133  0.741445     0.707692
# 22        45      0.703971   0.810659    0.786290  0.742857     0.707692
# 23        47      0.703971   0.810659    0.786290  0.742857     0.707692
# 24        49      0.703971   0.810659    0.786290  0.742857     0.707692
# 25        51      0.703971   0.810659    0.786290  0.742857     0.707692
# 26        53      0.703971   0.810659    0.786290  0.742857     0.707692
# 27        55      0.703971   0.810659    0.786290  0.742857     0.707692
# 28        57      0.703971   0.810659    0.786290  0.742857     0.707692
# 29        59      0.703971   0.810659    0.786290  0.742857     0.707692
# 30        61      0.703971   0.810659    0.786290  0.742857     0.707692
# 31        63      0.703971   0.810659    0.786290  0.742857     0.707692
# 32        65      0.703971   0.810659    0.786290  0.742857     0.707692
# 33        67      0.703971   0.810659    0.786290  0.742857     0.707692
# 34        69      0.703971   0.810659    0.786290  0.742857     0.707692
# 35        71      0.703971   0.810659    0.786290  0.742857     0.707692
# 36        73      0.703971   0.810659    0.786290  0.742857     0.707692
# 37        75      0.703971   0.810659    0.786290  0.742857     0.707692
# 38        77      0.703971   0.810659    0.786290  0.742857     0.707692
# 39        79      0.703971   0.810659    0.786290  0.742857     0.707692
# 40        81      0.703971   0.810659    0.786290  0.742857     0.707692
# 41        83      0.703971   0.810659    0.786290  0.742857     0.707692
# 42        85      0.703971   0.810659    0.786290  0.742857     0.707692
# 43        87      0.703971   0.810659    0.786290  0.742857     0.707692
# 44        89      0.703971   0.810659    0.786290  0.742857     0.707692
# 45        91      0.703971   0.810659    0.786290  0.742857     0.707692
# 46        93      0.703971   0.810659    0.786290  0.742857     0.707692
# 47        95      0.703971   0.810659    0.786290  0.742857     0.707692
# 48        97      0.703971   0.810659    0.786290  0.742857     0.707692
# 49        99      0.703971   0.810659    0.786290  0.742857     0.707692
#
#     acc_test  prec_test   f1_test
# 0   0.792135   0.718750  0.713178
# 1   0.797753   0.730159  0.718750
# 2   0.797753   0.730159  0.718750
# 3   0.797753   0.730159  0.718750
# 4   0.797753   0.730159  0.718750
# 5   0.797753   0.730159  0.718750
# 6   0.797753   0.730159  0.718750
# 7   0.797753   0.730159  0.718750
# 8   0.797753   0.730159  0.718750
# 9   0.797753   0.730159  0.718750
# 10  0.797753   0.730159  0.718750
# 11  0.797753   0.730159  0.718750
# 12  0.797753   0.730159  0.718750
# 13  0.797753   0.730159  0.718750
# 14  0.797753   0.730159  0.718750
# 15  0.797753   0.730159  0.718750
# 16  0.797753   0.730159  0.718750
# 17  0.797753   0.730159  0.718750
# 18  0.797753   0.730159  0.718750
# 19  0.797753   0.730159  0.718750
# 20  0.797753   0.730159  0.718750
# 21  0.797753   0.730159  0.718750
# 22  0.797753   0.730159  0.718750
# 23  0.797753   0.730159  0.718750
# 24  0.797753   0.730159  0.718750
# 25  0.797753   0.730159  0.718750
# 26  0.797753   0.730159  0.718750
# 27  0.797753   0.730159  0.718750
# 28  0.797753   0.730159  0.718750
# 29  0.797753   0.730159  0.718750
# 30  0.797753   0.730159  0.718750
# 31  0.797753   0.730159  0.718750
# 32  0.797753   0.730159  0.718750
# 33  0.797753   0.730159  0.718750
# 34  0.797753   0.730159  0.718750
# 35  0.797753   0.730159  0.718750
# 36  0.797753   0.730159  0.718750
# 37  0.797753   0.730159  0.718750
# 38  0.797753   0.730159  0.718750
# 39  0.797753   0.730159  0.718750
# 40  0.797753   0.730159  0.718750
# 41  0.797753   0.730159  0.718750
# 42  0.797753   0.730159  0.718750
# 43  0.797753   0.730159  0.718750
# 44  0.797753   0.730159  0.718750
# 45  0.797753   0.730159  0.718750
# 46  0.797753   0.730159  0.718750
# 47  0.797753   0.730159  0.718750
# 48  0.797753   0.730159  0.718750
# 49  0.797753   0.730159  0.718750

# %% [markdown]
# <div id='id-section2.5._'/>

# %% [markdown]
# ### 2.5. MLPClassifier

# %%
#MLPClassifier
nn = MLPClassifier(random_state=seed, max_iter=10000, hidden_layer_sizes=(10,),)
nn.fit(train_X, train_y)
preds_train = nn.predict(train_X) # предсказания для train_X 
preds_test = nn.predict(test_X) # предсказания для test_X
print('####### РЕЗУЛЬТАТЫ ДЛЯ ОБУЧЕНИЯ #######')
#print('hidden_size: ', hidden_layer_sizes)
print('Recall: ', round(recall_score(train_y, preds_train), 2))
print('Accuracy: ', round(accuracy_score(train_y, preds_train), 2))
print('Precision: ', round(precision_score(train_y, preds_train), 2))
print('F1 score: ', round(f1_score(train_y, preds_train), 2))

print('####### РЕЗУЛЬТАТЫ ДЛЯ ТЕСТА #######')
print('Recall: ', round(recall_score(test_y, preds_test), 2))
print('Accuracy: ', round(accuracy_score(test_y, preds_test), 2))
print('Precision: ', round(precision_score(test_y, preds_test),2))
print('F1 score: ', round(f1_score(test_y, preds_test), 2))

results = pd.DataFrame()
for hidden_size in range(1, 15):
    nn = MLPClassifier(hidden_layer_sizes=(hidden_size, ), random_state=seed, max_iter=10000)
    nn.fit(train_X, train_y)
    preds_train = nn.predict(train_X)
    preds_test = nn.predict(test_X)
    
    results_dict = {
                    'hidden_size':[hidden_size],
                    'recall_train':[recall_score(train_y, preds_train)], 
                    'acc_train':[recall_score(train_y, preds_train)],
                    'prec_train':[precision_score(train_y, preds_train)],
                    'f1_train':[f1_score(train_y, preds_train)],
                    'recall_test':[recall_score(test_y, preds_test)],
                    'acc_test':[accuracy_score(test_y, preds_test)],
                    'prec_test':[precision_score(test_y, preds_test)],
                    'f1_test':[f1_score(test_y, preds_test)]
                   }
    
    results_df = pd.DataFrame.from_dict(results_dict)
    results = results.append(results_df)

results.reset_index(inplace=True, drop=True)
# Out:
# ####### РЕЗУЛЬТАТЫ ДЛЯ ОБУЧЕНИЯ #######
# Recall:  0.7
# Accuracy:  0.79
# Precision:  0.75
# F1 score:  0.73
# ####### РЕЗУЛЬТАТЫ ДЛЯ ТЕСТА #######
# Recall:  0.75
# Accuracy:  0.82
# Precision:  0.75
# F1 score:  0.75

# %%
results[results.recall_test == results.recall_test.max()]
# Out:
#    hidden_size  recall_train  acc_train  prec_train  f1_train  recall_test  \
# 9           10      0.700361   0.700361    0.751938  0.725234     0.753846
#
#    acc_test  prec_test   f1_test
# 9  0.820225   0.753846  0.753846

# %% [markdown]
# <div id='id-section3_'/>

# %% [markdown]
# ## 3. Вывод

# %% [markdown]
# Рейтинг результатов теста Accuracy для тестовой выборки:
# 1. Лучше всего себя проявили модели GradientBoostingClassifier и MLPClassifier. Точность на тестовой выборке 0.82
# 2. Точность в 0.81 показала модель RandomForestClassifitest
# 3. Модели DecisionTreeClassifier и Logistic Regression показали одинаковую точность - 0.8
